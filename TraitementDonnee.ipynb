# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_path = "C:/Users/arthu/OneDrive/Documents/ESILV/ESILV A4/Software engineering"

csv_circuit = "/circuits.csv"
csv_constructor_results = "/constructor_results.csv"
csv_constructor_standings = "/constructor_standings.csv"
csv_constructors = "/constructors.csv"
csv_driver_standings = "/driver_standings.csv"
csv_drivers = "/drivers.csv"
csv_lap_times = "/lap_times.csv"
csv_pit_stops = "/pit_stops.csv"
csv_qualifying = "/qualifying.csv"
csv_races = "/races.csv"
csv_results = "/results.csv"
csv_seasons = "/seasons.csv"
csv_sprint_results = "/sprint_results.csv"
csv_status = "/status.csv"

# %%
df_circuit = pd.read_csv(file_path + csv_circuit)
df_constructor_results = pd.read_csv(file_path + csv_constructor_results)
df_constructor_standings = pd.read_csv(file_path + csv_constructor_standings)
df_constructors = pd.read_csv(file_path + csv_constructors)
df_driver_standings = pd.read_csv(file_path + csv_driver_standings)
df_drivers = pd.read_csv(file_path + csv_drivers)
df_lap_times = pd.read_csv(file_path + csv_lap_times)
df_pit_stops = pd.read_csv(file_path + csv_pit_stops)
df_qualifying = pd.read_csv(file_path + csv_qualifying)
df_races = pd.read_csv(file_path + csv_races)
df_results = pd.read_csv(file_path + csv_results)
df_seasons = pd.read_csv(file_path + csv_seasons)
df_sprint_results = pd.read_csv(file_path + csv_sprint_results)
df_status = pd.read_csv(file_path + csv_status)

# %%
df_constructor_results
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 0                         1      18              1    14.0     \N
# 1                         2      18              2     8.0     \N
# 2                         3      18              3     9.0     \N
# 3                         4      18              4     5.0     \N
# 4                         5      18              5     2.0     \N
# ...                     ...     ...            ...     ...    ...
# 12075                 16575    1086            117     1.0     \N
# 12076                 16576    1086            213     0.0     \N
# 12077                 16577    1086             51     0.0     \N
# 12078                 16578    1086            210     0.0     \N
# 12079                 16579    1086              3     0.0     \N
#
# [12080 rows x 5 columns]

# %%
df_drivers
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 849       851           aitken     89  AIT      Jack      Aitken  1995-09-23
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
#
# ...

# %%
df_constructors.join(df_drivers.set_index("nationality"), on = "nationality", lsuffix= True)
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 0                1        mclaren         McLaren     British
# 0                1        mclaren         McLaren     British
# 0                1        mclaren         McLaren     British
# 0                1        mclaren         McLaren     British
# ..             ...            ...             ...         ...
# 210            214         alpine  Alpine F1 Team      French
# 210            214         alpine  Alpine F1 Team      French
# 210            214         alpine  Alpine F1 Team      French
# 210            214         alpine  Alpine F1 Team      French
# 210            214         alpine  Alpine F1 Team      French
#
#                                          urlTrue  driverId      driverRef  \
# 0           http://en.wikipedia.org/wiki/McLaren       1.0       hamilton
# ...

# %%
nb_circuit_pays = df_circuit.groupby(by = "country").count().sort_values(by = ["circuitId", "country"], ascending = [False, True]).reset_index()[["country", "circuitId"]]
nb_circuit_pays.head(5)
# Out:
#     country  circuitId
# 0       USA         11
# 1    France          7
# 2     Spain          6
# 3     Italy          4
# 4  Portugal          4

# %%
nb_constructeur_pays = df_constructors.groupby(by = "nationality").count().sort_values(by = ["constructorId", "nationality"], ascending = [False, True]).reset_index()[["nationality", "constructorId"]]
nb_constructeur_pays.head(5)
# Out:
#   nationality  constructorId
# 0     British             86
# 1    American             39
# 2     Italian             29
# 3      French             13
# 4      German             10

# %%
nb_pilote_pays = df_drivers.groupby(by = "nationality").count().sort_values(by = ["driverId", "nationality"], ascending = [False, True]).reset_index()[["nationality", "driverId"]]
nb_pilote_pays.head(5)
# Out:
#   nationality  driverId
# 0     British       165
# 1    American       157
# 2     Italian        99
# 3      French        73
# 4      German        50

# %%
nb_constructeur_pilote_pays = nb_constructeur_pays.set_index("nationality").join(nb_pilote_pays.set_index("nationality"), on = "nationality").reset_index()
nb_constructeur_pilote_pays
# Out:
#       nationality  constructorId  driverId
# 0         British             86     165.0
# 1        American             39     157.0
# 2         Italian             29      99.0
# 3          French             13      73.0
# 4          German             10      50.0
# 5        Japanese              5      20.0
# 6           Swiss              5      23.0
# 7           Dutch              3      17.0
# 8   South African              3      23.0
# 9        Canadian              2      14.0
# 10      Malaysian              2       1.0
# 11        Russian              2       4.0
# 12     Australian              1      17.0
# 13       Austrian              1      15.0
# 14        Belgian              1      23.0
# 15      Brazilian              1      32.0
# 16    East German              1       3.0
# 17      Hong Kong              1       NaN
# 18         Indian              1       2.0
# 19          Irish              1       5.0
# 20        Mexican              1       6.0
# ...

# %%
fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
ax2 = ax.twinx()

x = nb_constructeur_pilote_pays["nationality"]
y = nb_constructeur_pilote_pays["constructorId"]
z = nb_constructeur_pilote_pays["driverId"]
  
X_axis = np.arange(len(x))
  
ax.bar(X_axis - 0.2, y, 0.4, color = "red", label = 'nombre de constructeurs')
ax2.bar(X_axis + 0.2, z, 0.4, color = "blue", label = 'nombre de pilotes')

ax.set_xticklabels(x, rotation = 90)
plt.xticks(X_axis, x, rotation = "vertical")
plt.xlabel("nationality")

fig.legend()
plt.show()
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_5068\2308891429.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation = 90)
